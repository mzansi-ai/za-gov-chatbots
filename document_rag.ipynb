# %%
# Create directory for your pdfs
# !mkdir pdfs
# Out:
# mkdir: cannot create directory ‘pdfs’: File exists

# %%
# Couple of recent acts / bills
# !wget https://www.gov.za/sites/default/files/gcis_document/202410/51463upstreampetroleumresourcesdevelopmentactno232024.pdf -P ./pdfs
# !wget https://www.gov.za/sites/default/files/gcis_document/202409/51258basiceducationlawsamendmentact32of2024.pdf -P ./pdfs
# !wget https://www.gov.za/sites/default/files/gcis_document/202409/51164nationalyouthdevelopmentagencyamendmentact22of2024.pdf -P ./pdfs
# !wget https://www.gov.za/sites/default/files/gcis_document/202410/b20-2024-global-minimum-tax.pdf -P ./pdfs
# Out:
# --2024-11-11 21:56:57--  https://www.gov.za/sites/default/files/gcis_document/202410/51463upstreampetroleumresourcesdevelopmentactno232024.pdf
# Resolving www.gov.za (www.gov.za)... 198.54.8.55
# Connecting to www.gov.za (www.gov.za)|198.54.8.55|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1316089 (1.3M) [application/pdf]
# Saving to: ‘./pdfs/51463upstreampetroleumresourcesdevelopmentactno232024.pdf’
#
# 51463upstreampetrol 100%[===================>]   1.25M  3.43MB/s    in 0.4s
#
# 2024-11-11 21:56:58 (3.43 MB/s) - ‘./pdfs/51463upstreampetroleumresourcesdevelopmentactno232024.pdf’ saved [1316089/1316089]
#
# --2024-11-11 21:56:58--  https://www.gov.za/sites/default/files/gcis_document/202409/51258basiceducationlawsamendmentact32of2024.pdf
# Resolving www.gov.za (www.gov.za)... 198.54.8.55
# Connecting to www.gov.za (www.gov.za)|198.54.8.55|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 802728 (784K) [application/pdf]
# ...

# %%
# Our constitution in different languages
# !wget https://www.justice.gov.za/constitution/SAConstitution-web-afr.pdf -P ./pdfs 
# !wget https://www.justice.gov.za/constitution/SAConstitution-web-afr.pdf -P ./pdfs
# !wget https://www.justice.gov.za/constitution/SAConstitution-web-eng-0.pdf -P ./pdfs
# !wget https://www.justice.gov.za/constitution/SAConstitution-web-eng-01.pdf -P ./pdfs
# !wget https://www.justice.gov.za/constitution/SAConstitution-web-eng-02.pdf -P ./pdfs
# !wget https://www.justice.gov.za/constitution/SAConstitution-web-eng-03.pdf -P ./pdfs
# !wget https://www.justice.gov.za/constitution/SAConstitution-web-eng-04.pdf -P ./pdfs
# !wget https://www.justice.gov.za/constitution/SAConstitution-web-eng-05.pdf -P ./pdfs
# !wget https://www.justice.gov.za/constitution/SAConstitution-web-eng-06.pdf -P ./pdfs
# !wget https://www.justice.gov.za/constitution/SAConstitution-web-eng-07.pdf -P ./pdfs
# !wget https://www.justice.gov.za/constitution/SAConstitution-web-eng-08.pdf -P ./pdfs
# !wget https://www.justice.gov.za/constitution/SAConstitution-web-eng-09.pdf -P ./pdfs
# !wget https://www.justice.gov.za/constitution/SAConstitution-web-eng-10.pdf -P ./pdfs
# !wget https://www.justice.gov.za/constitution/SAConstitution-web-eng-11.pdf -P ./pdfs
# !wget https://www.justice.gov.za/constitution/SAConstitution-web-eng-12.pdf -P ./pdfs
# !wget https://www.justice.gov.za/constitution/SAConstitution-web-eng-13.pdf -P ./pdfs
# !wget https://www.justice.gov.za/constitution/SAConstitution-web-eng-14.pdf -P ./pdfs
# !wget https://www.justice.gov.za/constitution/SAConstitution-web-eng-annex-a.pdf -P ./pdfs
# !wget https://www.justice.gov.za/constitution/SAConstitution-web-eng-annex-b.pdf -P ./pdfs
# !wget https://www.justice.gov.za/constitution/SAConstitution-web-eng-annex-c.pdf -P ./pdfs
# !wget https://www.justice.gov.za/constitution/SAConstitution-web-eng-annex-d.pdf -P ./pdfs
# !wget https://www.justice.gov.za/constitution/SAConstitution-web-eng-index.pdf -P ./pdfs
# !wget https://www.justice.gov.za/constitution/SAConstitution-web-eng-s01.pdf -P ./pdfs
# !wget https://www.justice.gov.za/constitution/SAConstitution-web-eng-s02.pdf -P ./pdfs
# !wget https://www.justice.gov.za/constitution/SAConstitution-web-eng-s03.pdf -P ./pdfs
# !wget https://www.justice.gov.za/constitution/SAConstitution-web-eng-s04.pdf -P ./pdfs
# !wget https://www.justice.gov.za/constitution/SAConstitution-web-eng-s05.pdf -P ./pdfs
# !wget https://www.justice.gov.za/constitution/SAConstitution-web-eng-s06-a-b.pdf -P ./pdfs
# !wget https://www.justice.gov.za/constitution/SAConstitution-web-eng-s06.pdf -P ./pdfs
# !wget https://www.justice.gov.za/constitution/SAConstitution-web-eng-s07.pdf -P ./pdfs
# !wget https://www.justice.gov.za/constitution/SAConstitution-web-eng.pdf -P ./pdfs
# !wget https://www.justice.gov.za/constitution/SAConstitution-web-nde.pdf -P ./pdfs
# !wget https://www.justice.gov.za/constitution/SAConstitution-web-sep.pdf -P ./pdfs
# !wget https://www.justice.gov.za/constitution/SAConstitution-web-set.pdf -P ./pdfs
# !wget https://www.justice.gov.za/constitution/SAConstitution-web-sot.pdf -P ./pdfs
# !wget https://www.justice.gov.za/constitution/SAConstitution-web-swa.pdf -P ./pdfs
# !wget https://www.justice.gov.za/constitution/SAConstitution-web-tso.pdf -P ./pdfs
# !wget https://www.justice.gov.za/constitution/SAConstitution-web-ven.pdf -P ./pdfs
# !wget https://www.justice.gov.za/constitution/SAConstitution-web-xho.pdf -P ./pdfs
# Out:
# --2024-11-11 21:57:30--  https://www.justice.gov.za/constitution/SAConstitution-web-afr.pdf
# Resolving www.justice.gov.za (www.justice.gov.za)... 41.149.144.168
# Connecting to www.justice.gov.za (www.justice.gov.za)|41.149.144.168|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 564144 (551K) [application/pdf]
# Saving to: ‘./pdfs/SAConstitution-web-afr.pdf’
#
# SAConstitution-web- 100%[===================>] 550.92K  2.41MB/s    in 0.2s
#
# 2024-11-11 21:57:30 (2.41 MB/s) - ‘./pdfs/SAConstitution-web-afr.pdf’ saved [564144/564144]
#
# --2024-11-11 21:57:30--  https://www.justice.gov.za/constitution/SAConstitution-web-afr.pdf
# Resolving www.justice.gov.za (www.justice.gov.za)... 41.149.144.168
# Connecting to www.justice.gov.za (www.justice.gov.za)|41.149.144.168|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 564144 (551K) [application/pdf]
# Saving to: ‘./pdfs/SAConstitution-web-afr.pdf.1’
#
# ...

# %%
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from llama_index.llms.openai import OpenAI

Settings.llm = OpenAI(model="gpt-4o-mini")

# %%
documents = SimpleDirectoryReader('pdfs').load_data()
index = VectorStoreIndex.from_documents(documents, llm=settings.llm)
# Out:
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x77d82e14d430>>
# Traceback (most recent call last):
#   File "/home/goose/Development/elasticMeetupNov24/.venv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 775, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
#
# KeyboardInterrupt:

# %%
query_engine = index.as_query_engine()

# %%
context_prompt ="""
You are a useful chatbot for explaining and giving insight into the constit

# %%
def query(context_prompt: str="", prompt: str=""):
    response = query_engine.query(
        context_prompt + prompt
        )
    print(response)
    print("\n\n")
    for x in response.source_nodes:
        print(x)
        print(x.metadata)

# %%
query("Some question about the data should go here")
# Out:
# The text provided seems to be in a language other than English, possibly isiZulu or Sesotho. It appears to be discussing regulations or laws related to petroleum resources development. The content mentions aspects like ensuring compliance with specified values and the allocation of rights for petroleum use.
#
#
#
# Node ID: f5bb0969-23ce-41df-81b1-651d4c82fe30
# Text: (2) UmNqophisizombelele kufanele aqinisekise nofana abekele
# ngeqadi umlayo ohlathululwe esigatjaneni (1).5 10 15 20 25 30 35 40 45
# 50 5591
# Score:  0.762
#
# {'page_label': '91', 'file_name': '51463upstreampetroleumresourcesdevelopmentactno232024.pdf', 'file_path': '/home/goose/Development/elasticMeetupNov24/pdfs/51463upstreampetroleumresourcesdevelopmentactno232024.pdf', 'file_type': 'application/pdf', 'file_size': 1316089, 'creation_date': '2024-11-11', 'last_modified_date': '2024-10-31'}
# Node ID: 0e389c2d-5c20-4ec9-bc3f-31e97b5f7631
# Text: (7) Go hlathwa ga mabaka le dipeelano ts ˇa tokelo ya go diris
# ...

# %%
print(response.source_nodes)

# %%
question_en = "What are the The official languages of the Republic"
question_xhoza = "Zithini Iilwimi ezisemthethweni zeRiphabhliki"
question_zulu = "What are the The official languages of the Republic"

# %%
print(query_engine.retrieve(
        question_en
        ))
print("\n\n")
print(query_engine.query(
        question_en
        ))
# Out:
# [NodeWithScore(node=TextNode(id_='e2f0e492-1619-4210-b4c0-6e636132b13c', embedding=None, metadata={'page_label': '4', 'file_name': 'SAConstitution-web-eng.pdf', 'file_path': '/home/goose/Development/elasticMeetupNov24/pdfs/SAConstitution-web-eng.pdf', 'file_type': 'application/pdf', 'file_size': 664767, 'creation_date': '2024-11-11', 'last_modified_date': '2023-03-15'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='47192937-3ed5-447b-ad8a-5e621975be8b', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'page_label': '4', 'file_name': 'SAConstitution-web-eng.pdf', 'file_path': '/home/goose/Development/elasticMeetupNov24/pdfs/SAConstitution-web-eng.pdf', 'file_type': 'application/pdf', 'file_size': 664767, 
# ...

# %%
print(query_engine.retrieve(
        question_xhoza
        ))
print("\n\n")
print(query_engine.query(
        question_xhoza
        ))
# Out:
# [NodeWithScore(node=TextNode(id_='63c0c5ef-459b-4a1d-af9c-de9a40683ee3', embedding=None, metadata={'page_label': '4', 'file_name': 'SAConstitution-web-xho.pdf', 'file_path': '/home/goose/Development/elasticMeetupNov24/pdfs/SAConstitution-web-xho.pdf', 'file_type': 'application/pdf', 'file_size': 641480, 'creation_date': '2024-11-11', 'last_modified_date': '2023-03-15'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='cb1371ae-8c5e-487c-ba13-c472a55cbe18', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'page_label': '4', 'file_name': 'SAConstitution-web-xho.pdf', 'file_path': '/home/goose/Development/elasticMeetupNov24/pdfs/SAConstitution-web-xho.pdf', 'file_type': 'application/pdf', 'file_size': 641480, 
# ...
